# %% [markdown]
# # CIC Dataset — Preprocessing & Feature Selection
#
# **Artifact-driven analysis**

# %%
from pathlib import Path
import pandas as pd
import numpy as np

RESULTS_ROOT = Path("/content/results")
OUT_DIR = RESULTS_ROOT / "preprocessing_feature_selection"
OUT_DIR.mkdir(parents=True, exist_ok=True)

print("Output:", OUT_DIR)
# Out:
# Output: /content/results/preprocessing_feature_selection

# %%
plan = pd.DataFrame([
    ["schema hygiene", "normalize column names consistently"],
    ["infinite values", "convert +/-inf to NaN before treatment"],
    ["missing values", "define treatment from observed prevalence"],
    ["constant features", "remove from modelling features"],
    ["near-constant features", "review before removal"],
    ["high correlation", "review redundant features using training data only"],
    ["scaling", "fit model-specific scaler on training data only"],
    ["duplicates", "handle before splitting where appropriate"],
    ["class imbalance", "address only after leakage-safe splitting"],
    ["rare classes", "document validation limitations"],
    ["capture sessions", "consider file/session-aware splitting"],
], columns=["decision_area","planned_action"])

display(plan)
plan.to_csv(OUT_DIR/"preprocessing_plan.csv", index=False)
# Out:
#              decision_area                                     planned_action
# 0           schema hygiene                normalize column names consistently
# 1          infinite values             convert +/-inf to NaN before treatment
# 2           missing values          define treatment from observed prevalence
# 3        constant features                     remove from modelling features
# 4   near-constant features                              review before removal
# 5         high correlation  review redundant features using training data ...
# 6                  scaling    fit model-specific scaler on training data only
# 7               duplicates          handle before splitting where appropriate
# 8          class imbalance          address only after leakage-safe splitting
# 9             rare classes                    document validation limitations
# 10        capture sessions              consider file/session-aware splitting

# %% [markdown]
# ## Conclusion
#
# Document mandatory transformations, candidate feature removals, model-specific transformations, and leakage-safe splitting. Do not train the final model here.
